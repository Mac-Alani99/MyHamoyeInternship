# %%
import pandas as pd
import numpy as np
fd_dt= pd.read_csv(r"C:\Users\USER\Downloads\FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding="latin1")
fd_dt
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
fd_dt.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
fd_dt.groupby('Area Code')['Area Code'].count()
# Out:
# Area Code
# 4      1313
# 7      1424
# 20     1378
# 32     1460
# 35     1260
# 37     1344
# 39     1343
# 45       45
# 46     1413
# 53     1285
# 59     1488
# 62       39
# 72     1095
# 74     1245
# 75     1168
# 81     1354
# 90     1410
# 107    1467
# 114    1560
# 122    1150
# 123    1206
# 129    1439
# 130    1447
# 133    1293
# 136    1195
# 137    1378
# 143    1393
# 144    1427
# 147    1283
# 158    1403
# 159    1474
# 175    1128
# 181    1393
# 184    1426
# 193    1177
# 195    1462
# 196      68
# 197    1242
# 202    1399
# 206      53
# 209    1284
# 215    1419
# 217    1294
# 222    1338
# 226    1458
# 233    1409
# 238    1447
# 251    1451
# 276    1316
# Name: Area Code, dtype: int64

# %%
grp = fd_dt.groupby(by='Area Code')
grp.sum()
grp
# Out:
#            Item Code  Element Code       Y2014       Y2015       Y2016  \
# Area Code
# 4            3532053       5017927   313375.33   324058.40   326007.41
# 7            3819908       5515088   208584.42   209565.67   214725.32
# 20           3704902       5259784    22339.92    23024.85    22970.65
# 32           3916078       5663196   217630.28   225220.72   231714.36
# 35           3396746       4787751    14576.94    14538.93    14569.40
# 37           3607546       5069094    28739.02    28885.34    29454.54
# 39           3606529       5108355    65940.17    65835.88    72673.76
# 45            124514        241681       32.00       41.34       54.91
# 46           3792029       5445560    38699.26    40255.51    40592.66
# 53           3453692       4852820   118050.79   108181.13   117963.59
# 59           3996567       5893126   849192.30   868218.73   858568.63
# 62            107853        209609        0.00        0.00        0.00
# ...

# %%
np.unique(fd_dt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15320\3593991036.py in <module>
# ----> 1 np.unique(fd_dt)
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     270     ar = np.asanyarray(ar)
#     271     if axis is None:
# --> 272         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     273         return _unpack_tuple(ret)
#     274
#
# ~\anaconda3\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     331         aux = ar[perm]
#     332     else:
# --> 333         ar.sort()
#     334         aux = ar
#     335     mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'str' and 'int'
